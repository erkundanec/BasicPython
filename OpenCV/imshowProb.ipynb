# %%
import cv2
# %matplotlib inline
from matplotlib import pyplot as plt
img = cv2.imread("myWatch.jpeg")

# %%
img = cv2.imread('myWatch.jpeg',0)

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
