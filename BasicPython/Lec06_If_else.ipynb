# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Control-Flow-Statements" data-toc-modified-id="Control-Flow-Statements-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Control Flow Statements</a></span><ul class="toc-item"><li><span><a href="#if-Statements" data-toc-modified-id="if-Statements-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>if Statements</a></span></li><li><span><a href="#if-else-Statements" data-toc-modified-id="if-else-Statements-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>if-else Statements</a></span></li><li><span><a href="#if-elif-Statements" data-toc-modified-id="if-elif-Statements-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>if-elif Statements</a></span></li><li><span><a href="#Nested-if-else" data-toc-modified-id="Nested-if-else-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Nested if-else</a></span></li></ul></li></ul></div>

# %% [markdown]
# # If-else Conditions

# %%
import os
from IPython.core.display import HTML
def load_style(directory = '../', name='customMac.css'):
        styles = open(os.path.join(directory, name), 'r').read()
        return HTML(styles)
load_style()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Lora');
#
# .CodeMirror pre, .CodeMirror-dialog, .CodeMirror-dialog .CodeMirror-search-field, .terminal-app .terminal {
#     font-family: YOUR-FAV-FONT;
#     font-size: 16pt;
# }
#
# .CodeMirror pre {
#     font-family: "Ubuntu", monospace;
# }
#     div.cell{
#         width: 950px;
#         margin-left: 0% !important;
#         margin-right: auto;
#     }
#     div.text_cell_render{
#         font-family: 'Lora';
#         line-height: 125%;
#         font-size: 130%;
#         text-align: justify;
#         text-justify:inter-word;
#     }
#     div.text_cell code {
#         background: transparent;
#         color: #000000;
#         font-weight: 400;
#         font-size: 12pt;
#         font-family:  'Source Code Pro', Consolas, monocco, monospace;
#    }
#     h1 {
#         font-family: "Ubuntu";
# 	}
#
#     div.input_area {
# ...

# %% [markdown]
# ## Control Flow Statements

# %% [markdown]
# ### if Statements
# Perhaps the most well-known statement type is the `if` statement. For example:
# ```
# if some_condition:
#     algorithm
# ```

# %%
x = 12
if x >10:
    print("Hello")
# Out:
# Hello

# %% [markdown]
# ### if-else Statements
# ```
# if some_condition:
#     algorithm
# else:
#     algorithm
# ```

# %%
x = 12
if x > 10:
    print("hello")
else:
    print("world")
# Out:
# hello

# %% [markdown]
# ### if-elif Statements
# ```
# if some_condition:
#     algorithm
# elif some_condition:
#     algorithm
# else:
#     algorithm
# ```

# %%
x = 10
y = 12

if x > y:
    print("x>y")
elif x < y:
    print("x<y")
else:
    print("x=y")
# Out:
# x<y

# %% [markdown]
# There can be zero or more `elif` parts, and the `else` part is optional. The keyword `elif` is short for `else if`, and is useful to avoid excessive indentation. An
# ```
# if some_condition:
#     algorithm
# elif some_condition:
#     algorithm
# elif:
#     algorithm
# ```
# sequence is a substitute for the `switch` or `case` statements found in other languages.

# %% [markdown]
# ### Nested if-else
# if statement inside a `if` statement or `if-elif` or `if-else` are called as nested `if` statements.

# %%
x = 11
y = 12
if x > y:
    print("x>y")
elif x < y:
    print("x<y")
    if x==10:
        print("x=10")
    else:
        print("invalid")
else:
    print("x=y")
# Out:
# x<y
# invalid
